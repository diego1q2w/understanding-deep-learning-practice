# %%
from config import ExperimentConfig
from trainer_utils import create_and_run_trainner
import matplotlib.pyplot as plt

# %%
config = ExperimentConfig.load_with_overrides(
    'configs/base.yaml',
    'configs/no_batchnorm.yaml'
)

# %%
results = create_and_run_trainner(config)
# Out:
# device:  mps
#
# ======================================================================
#                           🚀 TRAINING STARTED
# ======================================================================
#
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch   1/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:38, 40.96it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 169.42it/s]
# 📊 Results:
#    Train → Loss:  1.8195  |  Acc:  30.83%
#    Val   → Loss:  1.5669  |  Acc:  40.19%
#    ⏱️  Time: 40.01s
#    📉 Gradients: μ=1.82e-04, σ=3.85e-04, range=[9.45e-06, 1.68e-03]
#    📚 Learning Rate: 0.010000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch   2/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:34, 45.54it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 165.16it/s]
# 📊 Results:
#    Train → Loss:  1.4576  |  Acc:  45.71%
#    Val   → Loss:  1.2753  |  Acc:  52.71%
#    ⏱️  Time: 36.22s
#    Change: Acc ↗️ +12.52%  |  Loss ↘️ -0.2916
#    📉 Gradients: μ=2.34e-04, σ=4.58e-04, range=[1.27e-05, 1.90e-03]
#    📚 Learning Rate: 0.010000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch   3/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:34, 45.79it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 171.98it/s]
# 📊 Results:
#    Train → Loss:  1.2106  |  Acc:  56.32%
#    Val   → Loss:  1.1719  |  Acc:  59.07%
#    ⏱️  Time: 35.96s
#    Change: Acc ↗️ +6.36%  |  Loss ↘️ -0.1034
#    📉 Gradients: μ=2.62e-04, σ=4.83e-04, range=[1.43e-05, 1.97e-03]
#    📚 Learning Rate: 0.010000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch   4/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:34, 45.31it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 172.51it/s]
# 📊 Results:
#    Train → Loss:  1.0549  |  Acc:  61.96%
#    Val   → Loss:  0.9253  |  Acc:  66.88%
#    ⏱️  Time: 36.31s
#    Change: Acc ↗️ +7.81%  |  Loss ↘️ -0.2466
#    📉 Gradients: μ=2.63e-04, σ=4.85e-04, range=[1.43e-05, 1.99e-03]
#    📚 Learning Rate: 0.010000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch   5/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:34, 44.81it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 165.91it/s]
# 📊 Results:
#    Train → Loss:  0.9373  |  Acc:  66.65%
#    Val   → Loss:  0.9120  |  Acc:  68.05%
#    ⏱️  Time: 36.77s
#    Change: Acc ↗️ +1.17%  |  Loss ↘️ -0.0133
#    📉 Gradients: μ=2.61e-04, σ=4.81e-04, range=[1.41e-05, 1.99e-03]
#    📚 Learning Rate: 0.010000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch   6/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:35, 44.28it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 172.61it/s]
# 📊 Results:
#    Train → Loss:  0.8545  |  Acc:  69.71%
#    Val   → Loss:  0.8256  |  Acc:  71.08%
#    ⏱️  Time: 37.11s
#    Change: Acc ↗️ +3.03%  |  Loss ↘️ -0.0864
#    📉 Gradients: μ=2.62e-04, σ=4.89e-04, range=[1.39e-05, 2.03e-03]
#    📚 Learning Rate: 0.010000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch   7/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.29it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 167.30it/s]
# 📊 Results:
#    Train → Loss:  0.7837  |  Acc:  72.43%
#    Val   → Loss:  0.8254  |  Acc:  71.89%
#    ⏱️  Time: 35.64s
#    Change: Acc ↗️ +0.81%  |  Loss ↘️ -0.0003
#    📉 Gradients: μ=2.61e-04, σ=4.85e-04, range=[1.37e-05, 2.02e-03]
#    📚 Learning Rate: 0.010000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch   8/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:34, 44.83it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 174.93it/s]
# 📊 Results:
#    Train → Loss:  0.7242  |  Acc:  74.88%
#    Val   → Loss:  0.7853  |  Acc:  73.76%
#    ⏱️  Time: 36.66s
#    Change: Acc ↗️ +1.87%  |  Loss ↘️ -0.0400
#    📉 Gradients: μ=2.60e-04, σ=4.88e-04, range=[1.38e-05, 2.03e-03]
#    📚 Learning Rate: 0.010000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch   9/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.56it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 174.45it/s]
# 📊 Results:
#    Train → Loss:  0.6727  |  Acc:  76.59%
#    Val   → Loss:  0.7052  |  Acc:  75.46%
#    ⏱️  Time: 35.36s
#    Change: Acc ↗️ +1.70%  |  Loss ↘️ -0.0802
#    📉 Gradients: μ=2.61e-04, σ=4.91e-04, range=[1.38e-05, 2.05e-03]
#    📚 Learning Rate: 0.010000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  10/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.50it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 174.09it/s]
# 📊 Results:
#    Train → Loss:  0.6356  |  Acc:  78.05%
#    Val   → Loss:  0.6928  |  Acc:  77.04%
#    ⏱️  Time: 35.41s
#    Change: Acc ↗️ +1.58%  |  Loss ↘️ -0.0124
#    📉 Gradients: μ=2.56e-04, σ=4.82e-04, range=[1.37e-05, 2.02e-03]
#    📚 Learning Rate: 0.010000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  11/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.52it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 164.18it/s]
# 📊 Results:
#    Train → Loss:  0.6022  |  Acc:  79.16%
#    Val   → Loss:  0.6429  |  Acc:  78.31%
#    ⏱️  Time: 35.51s
#    Change: Acc ↗️ +1.27%  |  Loss ↘️ -0.0499
#    📉 Gradients: μ=2.58e-04, σ=4.91e-04, range=[1.36e-05, 2.05e-03]
#    📚 Learning Rate: 0.010000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  12/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.67it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 175.36it/s]
# 📊 Results:
#    Train → Loss:  0.5803  |  Acc:  80.15%
#    Val   → Loss:  0.6723  |  Acc:  77.89%
#    ⏱️  Time: 35.28s
#    Change: Acc ↘️ -0.42%  |  Loss ↗️ +0.0294
#    📉 Gradients: μ=2.57e-04, σ=4.91e-04, range=[1.33e-05, 2.05e-03]
#    📚 Learning Rate: 0.010000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  13/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.85it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 174.74it/s]
# 📊 Results:
#    Train → Loss:  0.5591  |  Acc:  80.45%
#    Val   → Loss:  0.5886  |  Acc:  80.80%
#    ⏱️  Time: 35.16s
#    Change: Acc ↗️ +2.91%  |  Loss ↘️ -0.0837
#    📉 Gradients: μ=2.59e-04, σ=4.93e-04, range=[1.32e-05, 2.06e-03]
#    📚 Learning Rate: 0.010000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  14/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.65it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 168.15it/s]
# 📊 Results:
#    Train → Loss:  0.5470  |  Acc:  81.06%
#    Val   → Loss:  0.6242  |  Acc:  79.40%
#    ⏱️  Time: 35.37s
#    Change: Acc ↘️ -1.40%  |  Loss ↗️ +0.0356
#    📉 Gradients: μ=2.60e-04, σ=4.96e-04, range=[1.34e-05, 2.08e-03]
#    📚 Learning Rate: 0.010000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  15/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.64it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 175.16it/s]
# 📊 Results:
#    Train → Loss:  0.5248  |  Acc:  81.86%
#    Val   → Loss:  0.5578  |  Acc:  81.87%
#    ⏱️  Time: 35.30s
#    Change: Acc ↗️ +2.47%  |  Loss ↘️ -0.0664
#    📉 Gradients: μ=2.60e-04, σ=4.97e-04, range=[1.33e-05, 2.08e-03]
#    📚 Learning Rate: 0.010000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  16/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.86it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 176.34it/s]
# 📊 Results:
#    Train → Loss:  0.5087  |  Acc:  82.46%
#    Val   → Loss:  0.5770  |  Acc:  81.20%
#    ⏱️  Time: 35.13s
#    Change: Acc ↘️ -0.67%  |  Loss ↗️ +0.0192
#    📉 Gradients: μ=2.60e-04, σ=4.97e-04, range=[1.32e-05, 2.08e-03]
#    📚 Learning Rate: 0.010000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  17/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.51it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 175.42it/s]
# 📊 Results:
#    Train → Loss:  0.4955  |  Acc:  82.92%
#    Val   → Loss:  0.5431  |  Acc:  82.06%
#    ⏱️  Time: 35.39s
#    Change: Acc ↗️ +0.86%  |  Loss ↘️ -0.0339
#    📉 Gradients: μ=2.62e-04, σ=5.02e-04, range=[1.33e-05, 2.11e-03]
#    📚 Learning Rate: 0.010000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  18/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.72it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 173.61it/s]
# 📊 Results:
#    Train → Loss:  0.4868  |  Acc:  83.21%
#    Val   → Loss:  0.5820  |  Acc:  81.30%
#    ⏱️  Time: 35.26s
#    Change: Acc ↘️ -0.76%  |  Loss ↗️ +0.0390
#    📉 Gradients: μ=2.60e-04, σ=5.00e-04, range=[1.33e-05, 2.10e-03]
#    📚 Learning Rate: 0.010000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  19/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.66it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 173.52it/s]
# 📊 Results:
#    Train → Loss:  0.4772  |  Acc:  83.47%
#    Val   → Loss:  0.4991  |  Acc:  83.10%
#    ⏱️  Time: 35.30s
#    Change: Acc ↗️ +1.80%  |  Loss ↘️ -0.0829
#    📉 Gradients: μ=2.59e-04, σ=4.99e-04, range=[1.32e-05, 2.10e-03]
#    📚 Learning Rate: 0.010000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  20/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.65it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 175.07it/s]
# 📊 Results:
#    Train → Loss:  0.4730  |  Acc:  83.68%
#    Val   → Loss:  0.5196  |  Acc:  82.85%
#    ⏱️  Time: 35.29s
#    Change: Acc ↘️ -0.25%  |  Loss ↗️ +0.0205
#    📉 Gradients: μ=2.62e-04, σ=5.03e-04, range=[1.33e-05, 2.11e-03]
#    📚 Learning Rate: 0.010000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  21/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.48it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 175.08it/s]
# 📊 Results:
#    Train → Loss:  0.3304  |  Acc:  88.49%
#    Val   → Loss:  0.4295  |  Acc:  86.07%
#    ⏱️  Time: 35.42s
#    Change: Acc ↗️ +3.22%  |  Loss ↘️ -0.0902
#    📉 Gradients: μ=2.15e-04, σ=4.13e-04, range=[1.12e-05, 1.75e-03]
#    📚 Learning Rate: 0.001000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  22/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.66it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 170.87it/s]
# 📊 Results:
#    Train → Loss:  0.2986  |  Acc:  89.55%
#    Val   → Loss:  0.4335  |  Acc:  86.23%
#    ⏱️  Time: 35.33s
#    Change: Acc ↗️ +0.16%  |  Loss ↗️ +0.0041
#    📉 Gradients: μ=2.11e-04, σ=4.04e-04, range=[1.14e-05, 1.71e-03]
#    📚 Learning Rate: 0.001000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  23/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 47.22it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 175.43it/s]
# 📊 Results:
#    Train → Loss:  0.2862  |  Acc:  90.05%
#    Val   → Loss:  0.4189  |  Acc:  86.75%
#    ⏱️  Time: 34.88s
#    Change: Acc ↗️ +0.52%  |  Loss ↘️ -0.0147
#    📉 Gradients: μ=2.12e-04, σ=4.06e-04, range=[1.15e-05, 1.72e-03]
#    📚 Learning Rate: 0.001000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  24/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 47.20it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 170.20it/s]
# 📊 Results:
#    Train → Loss:  0.2767  |  Acc:  90.38%
#    Val   → Loss:  0.4141  |  Acc:  86.89%
#    ⏱️  Time: 34.96s
#    Change: Acc ↗️ +0.14%  |  Loss ↘️ -0.0047
#    📉 Gradients: μ=2.14e-04, σ=4.09e-04, range=[1.18e-05, 1.74e-03]
#    📚 Learning Rate: 0.001000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  25/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 47.28it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 173.21it/s]
# 📊 Results:
#    Train → Loss:  0.2713  |  Acc:  90.54%
#    Val   → Loss:  0.4094  |  Acc:  87.12%
#    ⏱️  Time: 34.87s
#    Change: Acc ↗️ +0.23%  |  Loss ↘️ -0.0047
#    📉 Gradients: μ=2.14e-04, σ=4.06e-04, range=[1.18e-05, 1.72e-03]
#    📚 Learning Rate: 0.001000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  26/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.97it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 176.43it/s]
# 📊 Results:
#    Train → Loss:  0.2684  |  Acc:  90.56%
#    Val   → Loss:  0.4143  |  Acc:  86.94%
#    ⏱️  Time: 35.05s
#    Change: Acc ↘️ -0.18%  |  Loss ↗️ +0.0049
#    📉 Gradients: μ=2.16e-04, σ=4.08e-04, range=[1.20e-05, 1.73e-03]
#    📚 Learning Rate: 0.001000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  27/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.83it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 176.10it/s]
# 📊 Results:
#    Train → Loss:  0.2563  |  Acc:  91.05%
#    Val   → Loss:  0.4107  |  Acc:  87.16%
#    ⏱️  Time: 35.15s
#    Change: Acc ↗️ +0.22%  |  Loss ↘️ -0.0036
#    📉 Gradients: μ=2.17e-04, σ=4.12e-04, range=[1.21e-05, 1.75e-03]
#    📚 Learning Rate: 0.001000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  28/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 47.21it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 170.73it/s]
# 📊 Results:
#    Train → Loss:  0.2553  |  Acc:  91.10%
#    Val   → Loss:  0.4050  |  Acc:  87.59%
#    ⏱️  Time: 34.94s
#    Change: Acc ↗️ +0.43%  |  Loss ↘️ -0.0058
#    📉 Gradients: μ=2.18e-04, σ=4.11e-04, range=[1.23e-05, 1.75e-03]
#    📚 Learning Rate: 0.001000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  29/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 47.16it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 177.79it/s]
# 📊 Results:
#    Train → Loss:  0.2524  |  Acc:  91.04%
#    Val   → Loss:  0.4112  |  Acc:  87.19%
#    ⏱️  Time: 34.91s
#    Change: Acc ↘️ -0.40%  |  Loss ↗️ +0.0063
#    📉 Gradients: μ=2.19e-04, σ=4.13e-04, range=[1.24e-05, 1.76e-03]
#    📚 Learning Rate: 0.001000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  30/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.73it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 174.96it/s]
# 📊 Results:
#    Train → Loss:  0.2447  |  Acc:  91.40%
#    Val   → Loss:  0.4011  |  Acc:  87.48%
#    ⏱️  Time: 35.24s
#    Change: Acc ↗️ +0.29%  |  Loss ↘️ -0.0102
#    📉 Gradients: μ=2.19e-04, σ=4.15e-04, range=[1.21e-05, 1.77e-03]
#    📚 Learning Rate: 0.001000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  31/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.86it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 170.25it/s]
# 📊 Results:
#    Train → Loss:  0.2413  |  Acc:  91.49%
#    Val   → Loss:  0.4036  |  Acc:  87.11%
#    ⏱️  Time: 35.20s
#    Change: Acc ↘️ -0.37%  |  Loss ↗️ +0.0025
#    📉 Gradients: μ=2.21e-04, σ=4.16e-04, range=[1.24e-05, 1.78e-03]
#    📚 Learning Rate: 0.001000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  32/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.78it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 173.68it/s]
# 📊 Results:
#    Train → Loss:  0.2377  |  Acc:  91.55%
#    Val   → Loss:  0.4098  |  Acc:  87.35%
#    ⏱️  Time: 35.22s
#    Change: Acc ↗️ +0.24%  |  Loss ↗️ +0.0062
#    📉 Gradients: μ=2.23e-04, σ=4.21e-04, range=[1.27e-05, 1.80e-03]
#    📚 Learning Rate: 0.001000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  33/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 47.15it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 173.94it/s]
# 📊 Results:
#    Train → Loss:  0.2310  |  Acc:  91.91%
#    Val   → Loss:  0.4070  |  Acc:  87.70%
#    ⏱️  Time: 34.95s
#    Change: Acc ↗️ +0.35%  |  Loss ↘️ -0.0028
#    📉 Gradients: μ=2.19e-04, σ=4.13e-04, range=[1.24e-05, 1.77e-03]
#    📚 Learning Rate: 0.001000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  34/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.44it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 173.13it/s]
# 📊 Results:
#    Train → Loss:  0.2297  |  Acc:  91.93%
#    Val   → Loss:  0.4084  |  Acc:  87.55%
#    ⏱️  Time: 35.47s
#    Change: Acc ↘️ -0.15%  |  Loss ↗️ +0.0014
#    📉 Gradients: μ=2.23e-04, σ=4.19e-04, range=[1.27e-05, 1.79e-03]
#    📚 Learning Rate: 0.001000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  35/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.82it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 174.74it/s]
# 📊 Results:
#    Train → Loss:  0.2268  |  Acc:  91.99%
#    Val   → Loss:  0.4074  |  Acc:  87.59%
#    ⏱️  Time: 35.18s
#    Change: Acc ↗️ +0.04%  |  Loss ↘️ -0.0009
#    📉 Gradients: μ=2.24e-04, σ=4.19e-04, range=[1.26e-05, 1.80e-03]
#    📚 Learning Rate: 0.001000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  36/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.95it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 174.21it/s]
# 📊 Results:
#    Train → Loss:  0.2201  |  Acc:  92.22%
#    Val   → Loss:  0.4131  |  Acc:  87.38%
#    ⏱️  Time: 35.09s
#    Change: Acc ↘️ -0.21%  |  Loss ↗️ +0.0057
#    📉 Gradients: μ=2.24e-04, σ=4.19e-04, range=[1.27e-05, 1.80e-03]
#    📚 Learning Rate: 0.001000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  37/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.45it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 160.31it/s]
# 📊 Results:
#    Train → Loss:  0.2166  |  Acc:  92.37%
#    Val   → Loss:  0.4062  |  Acc:  87.73%
#    ⏱️  Time: 35.61s
#    Change: Acc ↗️ +0.35%  |  Loss ↘️ -0.0069
#    📉 Gradients: μ=2.27e-04, σ=4.25e-04, range=[1.29e-05, 1.83e-03]
#    📚 Learning Rate: 0.001000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  38/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.56it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 170.15it/s]
# 📊 Results:
#    Train → Loss:  0.2137  |  Acc:  92.45%
#    Val   → Loss:  0.4194  |  Acc:  87.69%
#    ⏱️  Time: 35.41s
#    Change: Acc ↘️ -0.04%  |  Loss ↗️ +0.0132
#    📉 Gradients: μ=2.27e-04, σ=4.25e-04, range=[1.30e-05, 1.83e-03]
#    📚 Learning Rate: 0.001000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  39/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:34, 45.66it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 163.14it/s]
# 📊 Results:
#    Train → Loss:  0.2108  |  Acc:  92.60%
#    Val   → Loss:  0.4146  |  Acc:  87.66%
#    ⏱️  Time: 36.15s
#    Change: Acc ↘️ -0.03%  |  Loss ↘️ -0.0047
#    📉 Gradients: μ=2.26e-04, σ=4.19e-04, range=[1.30e-05, 1.80e-03]
#    📚 Learning Rate: 0.001000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  40/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.28it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 171.82it/s]
# 📊 Results:
#    Train → Loss:  0.2097  |  Acc:  92.54%
#    Val   → Loss:  0.4174  |  Acc:  87.29%
#    ⏱️  Time: 35.60s
#    Change: Acc ↘️ -0.37%  |  Loss ↗️ +0.0028
#    📉 Gradients: μ=2.32e-04, σ=4.33e-04, range=[1.33e-05, 1.86e-03]
#    📚 Learning Rate: 0.001000
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  41/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.82it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 166.34it/s]
# 📊 Results:
#    Train → Loss:  0.1937  |  Acc:  93.19%
#    Val   → Loss:  0.4032  |  Acc:  87.88%
#    ⏱️  Time: 35.27s
#    Change: Acc ↗️ +0.59%  |  Loss ↘️ -0.0142
#    📉 Gradients: μ=2.15e-04, σ=3.98e-04, range=[1.23e-05, 1.71e-03]
#    📚 Learning Rate: 0.000100
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  42/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.81it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 167.30it/s]
# 📊 Results:
#    Train → Loss:  0.1892  |  Acc:  93.39%
#    Val   → Loss:  0.4067  |  Acc:  87.79%
#    ⏱️  Time: 35.27s
#    Change: Acc ↘️ -0.09%  |  Loss ↗️ +0.0034
#    📉 Gradients: μ=2.17e-04, σ=4.03e-04, range=[1.25e-05, 1.73e-03]
#    📚 Learning Rate: 0.000100
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  43/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.93it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 173.34it/s]
# 📊 Results:
#    Train → Loss:  0.1858  |  Acc:  93.45%
#    Val   → Loss:  0.4061  |  Acc:  87.98%
#    ⏱️  Time: 35.11s
#    Change: Acc ↗️ +0.19%  |  Loss ↘️ -0.0006
#    📉 Gradients: μ=2.17e-04, σ=4.03e-04, range=[1.25e-05, 1.73e-03]
#    📚 Learning Rate: 0.000100
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  44/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.80it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 175.53it/s]
# 📊 Results:
#    Train → Loss:  0.1851  |  Acc:  93.41%
#    Val   → Loss:  0.4053  |  Acc:  87.99%
#    ⏱️  Time: 35.19s
#    Change: Acc ↗️ +0.01%  |  Loss ↘️ -0.0008
#    📉 Gradients: μ=2.20e-04, σ=4.11e-04, range=[1.27e-05, 1.77e-03]
#    📚 Learning Rate: 0.000100
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  45/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.37it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 173.13it/s]
# 📊 Results:
#    Train → Loss:  0.1872  |  Acc:  93.48%
#    Val   → Loss:  0.4074  |  Acc:  88.07%
#    ⏱️  Time: 35.52s
#    Change: Acc ↗️ +0.08%  |  Loss ↗️ +0.0021
#    📉 Gradients: μ=2.20e-04, σ=4.09e-04, range=[1.28e-05, 1.76e-03]
#    📚 Learning Rate: 0.000100
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  46/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.83it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 176.58it/s]
# 📊 Results:
#    Train → Loss:  0.1843  |  Acc:  93.43%
#    Val   → Loss:  0.4044  |  Acc:  87.96%
#    ⏱️  Time: 35.15s
#    Change: Acc ↘️ -0.11%  |  Loss ↘️ -0.0030
#    📉 Gradients: μ=2.18e-04, σ=4.04e-04, range=[1.26e-05, 1.73e-03]
#    📚 Learning Rate: 0.000100
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  47/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.46it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 169.58it/s]
# 📊 Results:
#    Train → Loss:  0.1836  |  Acc:  93.54%
#    Val   → Loss:  0.4067  |  Acc:  88.00%
#    ⏱️  Time: 35.50s
#    Change: Acc ↗️ +0.04%  |  Loss ↗️ +0.0023
#    📉 Gradients: μ=2.19e-04, σ=4.06e-04, range=[1.27e-05, 1.75e-03]
#    📚 Learning Rate: 0.000100
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  48/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.80it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 174.61it/s]
# 📊 Results:
#    Train → Loss:  0.1825  |  Acc:  93.48%
#    Val   → Loss:  0.4086  |  Acc:  87.88%
#    ⏱️  Time: 35.19s
#    Change: Acc ↘️ -0.12%  |  Loss ↗️ +0.0019
#    📉 Gradients: μ=2.20e-04, σ=4.07e-04, range=[1.27e-05, 1.75e-03]
#    📚 Learning Rate: 0.000100
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  49/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.70it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 174.47it/s]
# 📊 Results:
#    Train → Loss:  0.1840  |  Acc:  93.56%
#    Val   → Loss:  0.4072  |  Acc:  87.90%
#    ⏱️  Time: 35.27s
#    Change: Acc ↗️ +0.02%  |  Loss ↘️ -0.0013
#    📉 Gradients: μ=2.20e-04, σ=4.09e-04, range=[1.27e-05, 1.76e-03]
#    📚 Learning Rate: 0.000100
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  50/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.90it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 176.46it/s]
# 📊 Results:
#    Train → Loss:  0.1842  |  Acc:  93.40%
#    Val   → Loss:  0.4078  |  Acc:  88.01%
#    ⏱️  Time: 35.10s
#    Change: Acc ↗️ +0.11%  |  Loss ↗️ +0.0006
#    📉 Gradients: μ=2.21e-04, σ=4.08e-04, range=[1.28e-05, 1.76e-03]
#    📚 Learning Rate: 0.000100
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  51/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.07it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 173.78it/s]
# 📊 Results:
#    Train → Loss:  0.1829  |  Acc:  93.56%
#    Val   → Loss:  0.4106  |  Acc:  87.98%
#    ⏱️  Time: 35.73s
#    Change: Acc ↘️ -0.03%  |  Loss ↗️ +0.0027
#    📉 Gradients: μ=2.20e-04, σ=4.08e-04, range=[1.29e-05, 1.76e-03]
#    📚 Learning Rate: 0.000100
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  52/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.40it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 173.25it/s]
# 📊 Results:
#    Train → Loss:  0.1788  |  Acc:  93.77%
#    Val   → Loss:  0.4101  |  Acc:  88.00%
#    ⏱️  Time: 35.49s
#    Change: Acc ↗️ +0.02%  |  Loss ↘️ -0.0005
#    📉 Gradients: μ=2.19e-04, σ=4.08e-04, range=[1.27e-05, 1.76e-03]
#    📚 Learning Rate: 0.000100
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  53/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.50it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 174.87it/s]
# 📊 Results:
#    Train → Loss:  0.1806  |  Acc:  93.64%
#    Val   → Loss:  0.4099  |  Acc:  87.93%
#    ⏱️  Time: 35.41s
#    Change: Acc ↘️ -0.07%  |  Loss ↘️ -0.0001
#    📉 Gradients: μ=2.19e-04, σ=4.06e-04, range=[1.28e-05, 1.75e-03]
#    📚 Learning Rate: 0.000100
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  54/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.69it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 170.85it/s]
# 📊 Results:
#    Train → Loss:  0.1792  |  Acc:  93.71%
#    Val   → Loss:  0.4095  |  Acc:  87.89%
#    ⏱️  Time: 35.33s
#    Change: Acc ↘️ -0.04%  |  Loss ↘️ -0.0004
#    📉 Gradients: μ=2.20e-04, σ=4.09e-04, range=[1.28e-05, 1.76e-03]
#    📚 Learning Rate: 0.000100
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  55/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.44it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 175.37it/s]
# 📊 Results:
#    Train → Loss:  0.1804  |  Acc:  93.67%
#    Val   → Loss:  0.4117  |  Acc:  87.81%
#    ⏱️  Time: 35.45s
#    Change: Acc ↘️ -0.08%  |  Loss ↗️ +0.0022
#    📉 Gradients: μ=2.24e-04, σ=4.14e-04, range=[1.31e-05, 1.78e-03]
#    📚 Learning Rate: 0.000100
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  56/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.91it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 167.10it/s]
# 📊 Results:
#    Train → Loss:  0.1796  |  Acc:  93.66%
#    Val   → Loss:  0.4112  |  Acc:  88.00%
#    ⏱️  Time: 35.20s
#    Change: Acc ↗️ +0.19%  |  Loss ↘️ -0.0005
#    📉 Gradients: μ=2.21e-04, σ=4.08e-04, range=[1.29e-05, 1.75e-03]
#    📚 Learning Rate: 0.000100
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  57/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.16it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 173.13it/s]
# 📊 Results:
#    Train → Loss:  0.1774  |  Acc:  93.77%
#    Val   → Loss:  0.4098  |  Acc:  88.00%
#    ⏱️  Time: 35.67s
#    Change: Acc → +0.00%  |  Loss ↘️ -0.0014
#    📉 Gradients: μ=2.21e-04, σ=4.07e-04, range=[1.29e-05, 1.75e-03]
#    📚 Learning Rate: 0.000100
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  58/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.76it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 171.17it/s]
# 📊 Results:
#    Train → Loss:  0.1783  |  Acc:  93.78%
#    Val   → Loss:  0.4112  |  Acc:  88.05%
#    ⏱️  Time: 35.26s
#    Change: Acc ↗️ +0.05%  |  Loss ↗️ +0.0013
#    📉 Gradients: μ=2.21e-04, σ=4.10e-04, range=[1.28e-05, 1.76e-03]
#    📚 Learning Rate: 0.000100
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  59/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.31it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 171.40it/s]
# 📊 Results:
#    Train → Loss:  0.1774  |  Acc:  93.79%
#    Val   → Loss:  0.4107  |  Acc:  87.93%
#    ⏱️  Time: 35.58s
#    Change: Acc ↘️ -0.12%  |  Loss ↘️ -0.0005
#    📉 Gradients: μ=2.22e-04, σ=4.09e-04, range=[1.29e-05, 1.76e-03]
#    📚 Learning Rate: 0.000100
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  60/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.65it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 175.04it/s]
# 📊 Results:
#    Train → Loss:  0.1769  |  Acc:  93.69%
#    Val   → Loss:  0.4109  |  Acc:  88.02%
#    ⏱️  Time: 35.30s
#    Change: Acc ↗️ +0.09%  |  Loss ↗️ +0.0003
#    📉 Gradients: μ=2.24e-04, σ=4.12e-04, range=[1.30e-05, 1.77e-03]
#    📚 Learning Rate: 0.000100
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  61/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.05it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 175.09it/s]
# 📊 Results:
#    Train → Loss:  0.1765  |  Acc:  93.75%
#    Val   → Loss:  0.4105  |  Acc:  88.04%
#    ⏱️  Time: 35.73s
#    Change: Acc ↗️ +0.02%  |  Loss ↘️ -0.0005
#    📉 Gradients: μ=2.23e-04, σ=4.12e-04, range=[1.30e-05, 1.78e-03]
#    📚 Learning Rate: 0.000010
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  62/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.45it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 175.75it/s]
# 📊 Results:
#    Train → Loss:  0.1762  |  Acc:  93.68%
#    Val   → Loss:  0.4106  |  Acc:  88.03%
#    ⏱️  Time: 35.43s
#    Change: Acc ↘️ -0.01%  |  Loss ↗️ +0.0001
#    📉 Gradients: μ=2.20e-04, σ=4.06e-04, range=[1.28e-05, 1.75e-03]
#    📚 Learning Rate: 0.000010
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  63/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.35it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 172.71it/s]
# 📊 Results:
#    Train → Loss:  0.1768  |  Acc:  93.88%
#    Val   → Loss:  0.4103  |  Acc:  88.03%
#    ⏱️  Time: 35.54s
#    Change: Acc → +0.00%  |  Loss ↘️ -0.0002
#    📉 Gradients: μ=2.20e-04, σ=4.06e-04, range=[1.29e-05, 1.75e-03]
#    📚 Learning Rate: 0.000010
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  64/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.67it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 172.14it/s]
# 📊 Results:
#    Train → Loss:  0.1741  |  Acc:  93.84%
#    Val   → Loss:  0.4099  |  Acc:  88.02%
#    ⏱️  Time: 35.31s
#    Change: Acc ↘️ -0.01%  |  Loss ↘️ -0.0004
#    📉 Gradients: μ=2.18e-04, σ=4.00e-04, range=[1.27e-05, 1.72e-03]
#    📚 Learning Rate: 0.000010
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  65/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:34, 45.86it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 173.55it/s]
# 📊 Results:
#    Train → Loss:  0.1740  |  Acc:  93.82%
#    Val   → Loss:  0.4098  |  Acc:  87.98%
#    ⏱️  Time: 35.89s
#    Change: Acc ↘️ -0.04%  |  Loss ↘️ -0.0001
#    📉 Gradients: μ=2.19e-04, σ=4.03e-04, range=[1.28e-05, 1.74e-03]
#    📚 Learning Rate: 0.000010
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  66/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:34, 45.66it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 168.86it/s]
# 📊 Results:
#    Train → Loss:  0.1747  |  Acc:  93.70%
#    Val   → Loss:  0.4098  |  Acc:  88.00%
#    ⏱️  Time: 36.09s
#    Change: Acc ↗️ +0.02%  |  Loss ↘️ -0.0000
#    📉 Gradients: μ=2.21e-04, σ=4.08e-04, range=[1.29e-05, 1.76e-03]
#    📚 Learning Rate: 0.000010
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  67/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:34, 45.49it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 170.39it/s]
# 📊 Results:
#    Train → Loss:  0.1734  |  Acc:  93.82%
#    Val   → Loss:  0.4100  |  Acc:  88.04%
#    ⏱️  Time: 36.20s
#    Change: Acc ↗️ +0.04%  |  Loss ↗️ +0.0002
#    📉 Gradients: μ=2.20e-04, σ=4.06e-04, range=[1.28e-05, 1.75e-03]
#    📚 Learning Rate: 0.000010
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  68/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:34, 45.91it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 170.37it/s]
# 📊 Results:
#    Train → Loss:  0.1740  |  Acc:  93.79%
#    Val   → Loss:  0.4104  |  Acc:  87.98%
#    ⏱️  Time: 35.88s
#    Change: Acc ↘️ -0.06%  |  Loss ↗️ +0.0004
#    📉 Gradients: μ=2.21e-04, σ=4.08e-04, range=[1.29e-05, 1.76e-03]
#    📚 Learning Rate: 0.000010
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  69/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:34, 45.43it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 171.40it/s]
# 📊 Results:
#    Train → Loss:  0.1718  |  Acc:  93.91%
#    Val   → Loss:  0.4105  |  Acc:  87.99%
#    ⏱️  Time: 36.23s
#    Change: Acc ↗️ +0.01%  |  Loss ↗️ +0.0001
#    📉 Gradients: μ=2.17e-04, σ=4.01e-04, range=[1.27e-05, 1.73e-03]
#    📚 Learning Rate: 0.000010
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  70/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:34, 45.14it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 169.81it/s]
# 📊 Results:
#    Train → Loss:  0.1736  |  Acc:  93.82%
#    Val   → Loss:  0.4104  |  Acc:  87.98%
#    ⏱️  Time: 36.48s
#    Change: Acc ↘️ -0.01%  |  Loss ↘️ -0.0001
#    📉 Gradients: μ=2.21e-04, σ=4.07e-04, range=[1.28e-05, 1.75e-03]
#    📚 Learning Rate: 0.000010
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  71/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:34, 45.49it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 156.58it/s]
# 📊 Results:
#    Train → Loss:  0.1734  |  Acc:  93.83%
#    Val   → Loss:  0.4103  |  Acc:  87.99%
#    ⏱️  Time: 36.36s
#    Change: Acc ↗️ +0.01%  |  Loss ↘️ -0.0001
#    📉 Gradients: μ=2.19e-04, σ=4.04e-04, range=[1.27e-05, 1.74e-03]
#    📚 Learning Rate: 0.000010
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  72/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:34, 45.92it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 173.92it/s]
# 📊 Results:
#    Train → Loss:  0.1739  |  Acc:  93.91%
#    Val   → Loss:  0.4105  |  Acc:  88.00%
#    ⏱️  Time: 35.84s
#    Change: Acc ↗️ +0.01%  |  Loss ↗️ +0.0001
#    📉 Gradients: μ=2.20e-04, σ=4.07e-04, range=[1.28e-05, 1.76e-03]
#    📚 Learning Rate: 0.000010
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  73/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.78it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 173.23it/s]
# 📊 Results:
#    Train → Loss:  0.1738  |  Acc:  93.81%
#    Val   → Loss:  0.4108  |  Acc:  88.03%
#    ⏱️  Time: 35.22s
#    Change: Acc ↗️ +0.03%  |  Loss ↗️ +0.0003
#    📉 Gradients: μ=2.21e-04, σ=4.09e-04, range=[1.29e-05, 1.76e-03]
#    📚 Learning Rate: 0.000010
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  74/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.24it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 173.45it/s]
# 📊 Results:
#    Train → Loss:  0.1754  |  Acc:  93.80%
#    Val   → Loss:  0.4104  |  Acc:  87.97%
#    ⏱️  Time: 35.61s
#    Change: Acc ↘️ -0.06%  |  Loss ↘️ -0.0004
#    📉 Gradients: μ=2.21e-04, σ=4.07e-04, range=[1.29e-05, 1.76e-03]
#    📚 Learning Rate: 0.000010
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  75/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.40it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 164.51it/s]
# 📊 Results:
#    Train → Loss:  0.1743  |  Acc:  93.87%
#    Val   → Loss:  0.4103  |  Acc:  88.07%
#    ⏱️  Time: 35.59s
#    Change: Acc ↗️ +0.10%  |  Loss ↘️ -0.0001
#    📉 Gradients: μ=2.21e-04, σ=4.09e-04, range=[1.29e-05, 1.76e-03]
#    📚 Learning Rate: 0.000010
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  76/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.62it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 176.09it/s]
# 📊 Results:
#    Train → Loss:  0.1754  |  Acc:  93.60%
#    Val   → Loss:  0.4103  |  Acc:  88.02%
#    ⏱️  Time: 35.31s
#    Change: Acc ↘️ -0.05%  |  Loss ↗️ +0.0000
#    📉 Gradients: μ=2.22e-04, σ=4.08e-04, range=[1.29e-05, 1.76e-03]
#    📚 Learning Rate: 0.000010
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  77/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.80it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 168.02it/s]
# 📊 Results:
#    Train → Loss:  0.1707  |  Acc:  93.90%
#    Val   → Loss:  0.4111  |  Acc:  88.02%
#    ⏱️  Time: 35.26s
#    Change: Acc → +0.00%  |  Loss ↗️ +0.0008
#    📉 Gradients: μ=2.18e-04, σ=4.03e-04, range=[1.27e-05, 1.74e-03]
#    📚 Learning Rate: 0.000010
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  78/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.28it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 172.37it/s]
# 📊 Results:
#    Train → Loss:  0.1717  |  Acc:  93.98%
#    Val   → Loss:  0.4115  |  Acc:  88.02%
#    ⏱️  Time: 35.60s
#    Change: Acc → +0.00%  |  Loss ↗️ +0.0004
#    📉 Gradients: μ=2.18e-04, σ=4.02e-04, range=[1.28e-05, 1.73e-03]
#    📚 Learning Rate: 0.000010
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  79/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.93it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 168.88it/s]
# 📊 Results:
#    Train → Loss:  0.1773  |  Acc:  93.74%
#    Val   → Loss:  0.4110  |  Acc:  87.98%
#    ⏱️  Time: 35.16s
#    Change: Acc ↘️ -0.04%  |  Loss ↘️ -0.0005
#    📉 Gradients: μ=2.24e-04, σ=4.14e-04, range=[1.30e-05, 1.79e-03]
#    📚 Learning Rate: 0.000010
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  80/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.07it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 170.66it/s]
# 📊 Results:
#    Train → Loss:  0.1755  |  Acc:  93.75%
#    Val   → Loss:  0.4113  |  Acc:  87.98%
#    ⏱️  Time: 35.76s
#    Change: Acc → +0.00%  |  Loss ↗️ +0.0003
#    📉 Gradients: μ=2.24e-04, σ=4.13e-04, range=[1.31e-05, 1.78e-03]
#    📚 Learning Rate: 0.000010
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  81/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.30it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 174.44it/s]
# 📊 Results:
#    Train → Loss:  0.1715  |  Acc:  93.89%
#    Val   → Loss:  0.4113  |  Acc:  87.99%
#    ⏱️  Time: 35.55s
#    Change: Acc ↗️ +0.01%  |  Loss ↘️ -0.0000
#    📉 Gradients: μ=2.19e-04, σ=4.03e-04, range=[1.29e-05, 1.74e-03]
#    📚 Learning Rate: 0.000001
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  82/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.40it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 164.76it/s]
# 📊 Results:
#    Train → Loss:  0.1720  |  Acc:  93.93%
#    Val   → Loss:  0.4113  |  Acc:  87.99%
#    ⏱️  Time: 35.59s
#    Change: Acc → +0.00%  |  Loss ↘️ -0.0000
#    📉 Gradients: μ=2.18e-04, σ=4.02e-04, range=[1.27e-05, 1.73e-03]
#    📚 Learning Rate: 0.000001
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  83/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.70it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 175.19it/s]
# 📊 Results:
#    Train → Loss:  0.1764  |  Acc:  93.69%
#    Val   → Loss:  0.4113  |  Acc:  87.97%
#    ⏱️  Time: 35.26s
#    Change: Acc ↘️ -0.02%  |  Loss ↗️ +0.0000
#    📉 Gradients: μ=2.24e-04, σ=4.14e-04, range=[1.30e-05, 1.79e-03]
#    📚 Learning Rate: 0.000001
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  84/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:34, 45.97it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 174.89it/s]
# 📊 Results:
#    Train → Loss:  0.1729  |  Acc:  93.99%
#    Val   → Loss:  0.4112  |  Acc:  87.98%
#    ⏱️  Time: 35.79s
#    Change: Acc ↗️ +0.01%  |  Loss ↘️ -0.0000
#    📉 Gradients: μ=2.21e-04, σ=4.09e-04, range=[1.29e-05, 1.76e-03]
#    📚 Learning Rate: 0.000001
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  85/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.58it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 175.42it/s]
# 📊 Results:
#    Train → Loss:  0.1731  |  Acc:  93.94%
#    Val   → Loss:  0.4112  |  Acc:  87.98%
#    ⏱️  Time: 35.34s
#    Change: Acc → +0.00%  |  Loss ↗️ +0.0000
#    📉 Gradients: μ=2.20e-04, σ=4.05e-04, range=[1.30e-05, 1.74e-03]
#    📚 Learning Rate: 0.000001
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  86/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:34, 45.64it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 176.10it/s]
# 📊 Results:
#    Train → Loss:  0.1733  |  Acc:  93.90%
#    Val   → Loss:  0.4112  |  Acc:  87.99%
#    ⏱️  Time: 36.02s
#    Change: Acc ↗️ +0.01%  |  Loss ↘️ -0.0000
#    📉 Gradients: μ=2.22e-04, σ=4.10e-04, range=[1.29e-05, 1.77e-03]
#    📚 Learning Rate: 0.000001
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  87/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.74it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 175.08it/s]
# 📊 Results:
#    Train → Loss:  0.1699  |  Acc:  94.03%
#    Val   → Loss:  0.4113  |  Acc:  87.98%
#    ⏱️  Time: 35.23s
#    Change: Acc ↘️ -0.01%  |  Loss ↗️ +0.0000
#    📉 Gradients: μ=2.19e-04, σ=4.05e-04, range=[1.28e-05, 1.75e-03]
#    📚 Learning Rate: 0.000001
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  88/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:34, 45.64it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 172.77it/s]
# 📊 Results:
#    Train → Loss:  0.1716  |  Acc:  93.90%
#    Val   → Loss:  0.4112  |  Acc:  87.98%
#    ⏱️  Time: 36.06s
#    Change: Acc → +0.00%  |  Loss ↘️ -0.0000
#    📉 Gradients: μ=2.22e-04, σ=4.10e-04, range=[1.29e-05, 1.77e-03]
#    📚 Learning Rate: 0.000001
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  89/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.07it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 171.31it/s]
# 📊 Results:
#    Train → Loss:  0.1729  |  Acc:  93.86%
#    Val   → Loss:  0.4112  |  Acc:  87.99%
#    ⏱️  Time: 35.75s
#    Change: Acc ↗️ +0.01%  |  Loss ↘️ -0.0000
#    📉 Gradients: μ=2.20e-04, σ=4.06e-04, range=[1.28e-05, 1.75e-03]
#    📚 Learning Rate: 0.000001
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  90/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:34, 45.57it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 169.71it/s]
# 📊 Results:
#    Train → Loss:  0.1745  |  Acc:  93.76%
#    Val   → Loss:  0.4112  |  Acc:  87.98%
#    ⏱️  Time: 36.14s
#    Change: Acc ↘️ -0.01%  |  Loss ↘️ -0.0000
#    📉 Gradients: μ=2.23e-04, σ=4.13e-04, range=[1.29e-05, 1.79e-03]
#    📚 Learning Rate: 0.000001
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  91/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.17it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 164.43it/s]
# 📊 Results:
#    Train → Loss:  0.1728  |  Acc:  93.90%
#    Val   → Loss:  0.4112  |  Acc:  87.97%
#    ⏱️  Time: 35.76s
#    Change: Acc ↘️ -0.01%  |  Loss ↘️ -0.0000
#    📉 Gradients: μ=2.22e-04, σ=4.11e-04, range=[1.30e-05, 1.77e-03]
#    📚 Learning Rate: 0.000001
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  92/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:34, 45.70it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 174.13it/s]
# 📊 Results:
#    Train → Loss:  0.1732  |  Acc:  93.87%
#    Val   → Loss:  0.4112  |  Acc:  88.00%
#    ⏱️  Time: 36.00s
#    Change: Acc ↗️ +0.03%  |  Loss ↘️ -0.0000
#    📉 Gradients: μ=2.20e-04, σ=4.07e-04, range=[1.28e-05, 1.75e-03]
#    📚 Learning Rate: 0.000001
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  93/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:34, 45.84it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 168.64it/s]
# 📊 Results:
#    Train → Loss:  0.1713  |  Acc:  94.02%
#    Val   → Loss:  0.4112  |  Acc:  88.00%
#    ⏱️  Time: 35.97s
#    Change: Acc → +0.00%  |  Loss ↗️ +0.0000
#    📉 Gradients: μ=2.20e-04, σ=4.07e-04, range=[1.28e-05, 1.76e-03]
#    📚 Learning Rate: 0.000001
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  94/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.27it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 167.64it/s]
# 📊 Results:
#    Train → Loss:  0.1763  |  Acc:  93.76%
#    Val   → Loss:  0.4111  |  Acc:  88.00%
#    ⏱️  Time: 35.66s
#    Change: Acc → +0.00%  |  Loss ↘️ -0.0000
#    📉 Gradients: μ=2.22e-04, σ=4.11e-04, range=[1.30e-05, 1.77e-03]
#    📚 Learning Rate: 0.000001
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  95/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:34, 45.51it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 173.63it/s]
# 📊 Results:
#    Train → Loss:  0.1717  |  Acc:  93.97%
#    Val   → Loss:  0.4112  |  Acc:  87.97%
#    ⏱️  Time: 36.15s
#    Change: Acc ↘️ -0.03%  |  Loss ↗️ +0.0000
#    📉 Gradients: μ=2.20e-04, σ=4.08e-04, range=[1.28e-05, 1.76e-03]
#    📚 Learning Rate: 0.000001
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  96/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.27it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 160.71it/s]
# 📊 Results:
#    Train → Loss:  0.1726  |  Acc:  93.86%
#    Val   → Loss:  0.4112  |  Acc:  87.99%
#    ⏱️  Time: 35.73s
#    Change: Acc ↗️ +0.02%  |  Loss ↘️ -0.0000
#    📉 Gradients: μ=2.23e-04, σ=4.14e-04, range=[1.30e-05, 1.79e-03]
#    📚 Learning Rate: 0.000001
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  97/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:34, 45.54it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 175.17it/s]
# 📊 Results:
#    Train → Loss:  0.1736  |  Acc:  93.88%
#    Val   → Loss:  0.4112  |  Acc:  87.97%
#    ⏱️  Time: 36.11s
#    Change: Acc ↘️ -0.02%  |  Loss ↗️ +0.0000
#    📉 Gradients: μ=2.20e-04, σ=4.07e-04, range=[1.29e-05, 1.76e-03]
#    📚 Learning Rate: 0.000001
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  98/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.00it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 166.84it/s]
# 📊 Results:
#    Train → Loss:  0.1722  |  Acc:  93.89%
#    Val   → Loss:  0.4112  |  Acc:  87.98%
#    ⏱️  Time: 35.86s
#    Change: Acc ↗️ +0.01%  |  Loss ↗️ +0.0001
#    📉 Gradients: μ=2.21e-04, σ=4.07e-04, range=[1.30e-05, 1.75e-03]
#    📚 Learning Rate: 0.000001
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch  99/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:34, 45.44it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 170.32it/s]
# 📊 Results:
#    Train → Loss:  0.1727  |  Acc:  93.84%
#    Val   → Loss:  0.4113  |  Acc:  87.98%
#    ⏱️  Time: 36.24s
#    Change: Acc → +0.00%  |  Loss ↗️ +0.0001
#    📉 Gradients: μ=2.20e-04, σ=4.06e-04, range=[1.30e-05, 1.75e-03]
#    📚 Learning Rate: 0.000001
#
# ──────────────────────────────────────────────────────────────────────
# 📍 Epoch 100/100
# ──────────────────────────────────────────────────────────────────────
# Training: 1563it [00:33, 46.09it/s]
# Validation: 100%|██████████| 313/313 [00:01<00:00, 174.80it/s]
# 📊 Results:
#    Train → Loss:  0.1761  |  Acc:  93.79%
#    Val   → Loss:  0.4113  |  Acc:  87.98%
#    ⏱️  Time: 35.71s
#    Change: Acc → +0.00%  |  Loss ↘️ -0.0000
#    📉 Gradients: μ=2.22e-04, σ=4.10e-04, range=[1.30e-05, 1.77e-03]
#    📚 Learning Rate: 0.000001
#
# ======================================================================
#                          ✅ TRAINING COMPLETE
# ======================================================================
#
# 📈 Final Results:
#    Best Val Acc:  88.07% (epoch 45)
#    Final Val Acc: 87.98%
#    Final Val Loss: 0.4113
#    Total Time: 59.3 minutes
# ======================================================================
#
# ✅ Saved results to results_nobn.pkl

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Loss
axes[0, 0].plot(results['train_losses'], label='Train')
axes[0, 0].plot(results['val_losses'], label='Val')
axes[0, 0].set_title('Loss')
axes[0, 0].set_xlabel('Epoch')
axes[0, 0].legend()

# Accuracy
axes[0, 1].plot(results['train_accs'], label='Train')
axes[0, 1].plot(results['val_accs'], label='Val')
axes[0, 1].set_title('Accuracy')
axes[0, 1].set_xlabel('Epoch')
axes[0, 1].legend()

# Gradient magnitudes over time
if results['gradient_history'] is not None:
    im = axes[1, 0].imshow(results['gradient_history'].T, aspect='auto', cmap='viridis')
    axes[1, 0].set_title('Gradient Magnitudes')
    axes[1, 0].set_xlabel('Epoch')
    axes[1, 0].set_ylabel('Conv Layer Index')
    plt.colorbar(im, ax=axes[1, 0])

# Epoch times
axes[1, 1].plot(results['epoch_times'])
axes[1, 1].set_title('Epoch Time')
axes[1, 1].set_xlabel('Epoch')
axes[1, 1].set_ylabel('Time (s)')

plt.tight_layout()
plt.show()
